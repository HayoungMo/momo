# %% [markdown]
# <a href="https://colab.research.google.com/github/HayoungMo/momo/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1주차 과제
# * * *
#
# 1. 언어 인공지능기술
#  * 번역기의 놀라운 발전.
# 2. 음성 인공지능기술
#  * 더 이상 입력하지 않아도 괜찮다.
# 3. 이미지 인공지능기술
#  * 사람의 눈만큼 정교해진 기계의 눈.
# 4. 자율주행 자동차 인공지능기술
#  * 딥러닝을 통해 이제는 자유롭게 운전이 가능하다.
#
# * * *
# **1. 언어 인공지능기술**
#  > 2000년 전후의 번역기들은 어딘가 다소 어색함이 존재 했었다. 또한,당시의 구글 번역기술의 SMT (Statistical Machine Translation)는 통계 기계 번역은 정확도가 떨어져서 대략적 의미만 파악이 가능했다. 하지만 2013년도 NMT가 등장했다. 순식간에 정확도가 올라갔고 2016년에는 번역 정확도의 지표인 Blue 스코어가 SMT의 약 20을 넘었으며 2018년에는 35를 넘어섰다. ~~35는 전달하는데 있어서 의미가 문제없고 문장자체도 자연스러운 수준이다.~~ 이 점수의 값은 스코어가 잘 나오지 않는 영어 - 독일어 번역이였다. 그래서 전문가들은 2020년도에는 번역 정확도가 60이상을 능가할것이라고 한다. ~~60은 평균적인 인간을 능가하는 수준이다.~~
#
# 출처 : 인공지능신문(http://www.aitimes.kr)
#
# **2. 음성 인공지능기술**
#  > 음성인식의 분야는 넓고도 또 가까웠다. 당장 우리가 항상 소지하는 핸드폰에만 봐도 언제든 인공지능비서가 존재한다. ~~시리,빅스비,헤이구글 등등.~~ 이제는 핸드폰을 넘어서 집에도 인공지능비서를 지니고 있을수 있다. 말만하면 노래재생,날씨정보,뉴스,스케줄 등 모든범위에서 우리는 손하나 까딱하지 않고 그 정보들을 얻을수 있다.~~구글의 에코 닷(알렉사), 카카오의 미니c(헤이카카오), KT의 기가지니 등등.~~ 다만, 이번에 음성에 관하여 찾아봤을때 필자에게 더 흥미롭게 다가온 주제를 발견했다. 다름아닌 통역기 였는데, 타임케틀의 WT2 라는 기기는 동시통역이 가능한 무선 이어폰이다. 36개 언어를 지원하고 통역이 필요한 순간 따로 어떠한 행동을 안취해도 된다. 번역 과정이 전용 앱과 연동되기 때문에 이어폰을 끼고 하고 싶은 말을 한다면 상대방에게 바로 번역된 음성으로 전달이된다고 한다. ~~아직까지는 동시통역시 15초의 간격과 5초의 딜레이가 존재한다.~~ 예전에는 직접 손으로 써서 해석으로 하고, 나중엔 핸드폰을 꺼내서 입력을 한 후에 번역을 해야했는데, 이제는 단순히 말만 하면 편하게 바뀐다는게 놀랍게 다가왔다.
#
# 타임케틀의 WT2 출처 : 네이버 블로그, 광화문 2번출구 (https://post.naver.com/viewer/postView.nhn?volumeNo=26062708&memberNo=16226184)
#
# **3. 이미지 인공지능기술**
#
#  > LG의 A.I 관련된 글을 읽어 보았는데, 이미지 인공기술은 많은 개발자들이 어려워하는 부분이라는걸 이번기회를 통해 알게되었다. 필자는 단순히 기계가 모를수가 있나? 했지만, 같은 사진도 노이즈가 살짝 있다면 기계는 그 사진을 다른 사물 또는 생명체로 인식을 한다고 한다.
# ~~![판다와 노이즈판다 그러나 오른쪽을 긴팔원숭이로 착각한다.](https://post.naver.com/viewer/postView.nhn?volumeNo=17875379&memberNo=39046504#)~~ 그래서 이러한 단점을 보안하기 위하여 인공신경망을 이용하여 특징을 포착과 추상화를 동시에 진행하게 된다고 한다. 그렇다면 이런 이미지 분석은 어디에 활용이 되나 싶더니, 여러분야에 적용이 가능하다고 했다. 하지만 가장 인상깊었던 부분을 소개하려한다. LG CSN의 AI이미지 분석기술을 이용한 전자제품에 들어가는 유리기판 제조 생산 공장에서 부품불량의 원인이 되는 기포와 먼지를 구별하는곳에 이용이 된다고 한다. 사람이 일일이 확인하는것보다 수월하며 심지어 오류 발생 확률을 낮추고 불량판정률을 높인다고 한다. 생각보다 더욱 디테일한 곳에서 현재 쓰인다는것이 매우 인상깊었다.
#
# 출처 : LG 네이버 블로그(https://post.naver.com/viewer/postView.nhn?volumeNo=17875379&memberNo=39046504)
#
# **4. 자율주행 자동차 인공지능기술**
#  > 이미 시행중인 자율주행 자동차의 시현영상이나 혹은 적은 부분을(~~앞 차에 가까워지면 알려주는것등.~~) 탑재한 광고들을 보았을때 솔직히 의심이 많이 갔다. 당시에는 기계를 100% 믿을수 있나? 싶은 생각이 들었는데, 이번 기회를 통해 내 생각이 잘못되었다는걸 깨달았다. 되려 기계가, 인공지능이 더 믿음직스럽지 않을까? 라는 질문이 떠올랐다. 인간의 많은 변수들을 인공지능에게 학습한다면 인공지능의 자동차는 순간 나오는 상황들을 빠르게 인지하여 어떠한 대처를 할 것 이다. 물론 100% 믿을수는 없지만 반대로 생각한다면 사람도 믿지 못하는건 마찬가지다. 다만 다른 점이 있다면 사람은 그때 판단으로 새로운 결론을 내리고 감각적으로 움직이는데, 인공지능은 아쉽게 그런능력이 없다. 이제 이런부분을 개발자, 우리가 알려줘야하는것이다. 어쩌면 멀지 않은 미래에 완벽에 가까운 자율주행 자동차가 많은 사람들이 이용하지 않을까?
#
#  출처 : SAMSUNG Newsrrom(https://news.samsung.com/kr/자율주행-자동차-딥러닝으로-시동-건다)
